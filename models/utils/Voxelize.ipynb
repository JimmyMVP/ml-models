# %%
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
import matplotlib
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from scipy import interpolate

# %%
#Matplotlib pointcloud visualization
data = np.genfromtxt("../dataset/objects/pedestrian.30.6994.csv", delimiter=",")
data = data[:,3:6]


x = data[:,0]
y = data[:,1]
z = data[:,2]



matplotlib.rcParams['legend.fontsize'] = 10


fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, label='pedestrian')
ax.legend()

plt.show()

# %%
data


grid = np.zeros((32,32,32))

x_grid, y_grid, z_grid = np.meshgrid(x, y, z, indexing='xy')

interpolate.griddata(data, grid,method="linear")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5881527eaaba> in <module>()
#       6 x_grid, y_grid, z_grid = np.meshgrid(x, y, z, indexing='xy')
#       7
# ----> 8 interpolate.griddata(data, grid,method="linear")
#       9
#
# TypeError: griddata() missing 1 required positional argument: 'xi'

# %%
#Voxelize the pointcloud
def voxel_grid(data, res=(32.0,32.0,32.0), limits=(25,25,25)):
    
    voxel_grid = np.zeros(shape=(X_RES, Y_RES, Z_RES))

    X_RES = res[0]
    Y_RES = res[1]
    Z_RES = res[2]
    limit = limits[0]

    for p in data:

        x,y,z = p[0],p[1],p[2]
        if abs(x) > limit:
            continue
        elif abs(y) > limit:
            continue
        elif abs(z) > limit:
            continue

        grid_x = int(np.ceil(((p[0]) / (2*limit))*X_RES))
        grid_y = int(np.ceil(((p[1]) / (2*limit))*Y_RES))
        grid_z = int(np.ceil(((p[2])) / (2*limit)*Z_RES))

        voxel_grid[grid_x][grid_y][grid_z]+=1.0

    return voxe
# Out:
# /Users/Jimmy/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel/__main__.py:6: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
matplotlib.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()
